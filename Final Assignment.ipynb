# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Jashandeep Kaur
# Data Analyst**

# %% [markdown]
# _I am interested in Data Science because it is interesting how we can use different analytic methods to help make business decisions_

# %% [markdown]
# ### My code will print hello world

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# - https://www.bloomberg.com/markets/stocks
#  > This link is an overview of the stock market in real time
# - ![bull-and-bear-stock-market-financial-bar-chart-vector-30566673.jpg](attachment:69688606-8f15-43b3-bd1b-cd3a3559b93f.jpg)
#  > This graphic shows the difference between bear and bull markets
